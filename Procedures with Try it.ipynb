# %% [markdown]
# # 1. Set Up the Project Environment

# %% [markdown]
# Step 1: Navigate to your Documents folder (or preferred directory)
# PS C:\Users\Allen\Documents> mkdir sql_python_lab
# PS C:\Users\Allen\Documents> cd sql_python_lab
#
# Step 2: Create a virtual environment
# PS C:\Users\Allen\Documents\sql_python_lab> py -m venv venv
#
# Step 3: Activate the virtual environment
# PS C:\Users\Allen\Documents\sql_python_lab> .\venv\Scripts\activate
#
# Step 4: Install Jupyter and the IPython kernel
# (venv) PS C:\Users\Allen\Documents\sql_python_lab> pip install notebook ipykernel
#
# Step 5: Register your virtual environment as a Jupyter kernel
# (venv) PS C:\Users\Allen\Documents\sql_python_lab> python -m ipykernel install -
# user --name=sql_lab_env --display-name "Python (SQL Lab)"

# %% [markdown]
# ## Try it part for No. 1:

# %%
pip list
# Out:
# Package                                  Version
# ---------------------------------------- --------------
# absl-py                                  2.3.1
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.4
# aiosignal                                1.4.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# anyio                                    4.10.0
# appdirs                                  1.4.4
# argon2-cffi                              25.1.0
# argon2-cffi-bindings                     25.1.0
# arrow                                    1.3.0
# asttokens                                3.0.0
# astunparse                               1.6.3
# async-lru                                2.0.5
# attrs                                    25.4.0
# babel                                    2.17.0
# bcrypt                                   5.0.0
# beautifulsoup4                           4.13.5
# bleach                                   6.2.0
# build                                    1.4.2
# cattrs                                   25.3.0
# certifi                                  2025.8.3
# cffi                                     2.0.0
# charset-normalizer                       3.4.3
# chromadb                                 1.5.5
# click                                    8.3.1
# colorama                                 0.4.6
# comm                                     0.2.3
# contourpy                                1.3.3
# cryptography                             46.0.6
# cycler                                   0.12.1
# dataclasses-json                         0.6.7
# debugpy                                  1.8.16
# decorator                                5.2.1
# define                                   1.74
# defusedxml                               0.7.1
# distro                                   1.9.0
# dm-tree                                  0.1.9
# docstring_parser                         0.17.0
# durationpy                               0.10
# einops                                   0.8.1
# etils                                    1.13.0
# executing                                2.2.0
# fastjsonschema                           2.21.2
# filelock                                 3.20.1
# filetype                                 1.2.0
# flatbuffers                              25.12.19
# fonttools                                4.61.1
# fqdn                                     1.5.1
# frozenlist                               1.8.0
# fsspec                                   2025.12.0
# gast                                     0.7.0
# geojson-rewind                           1.2.1
# geomet                                   1.1.0
# google-ai-generativelanguage             0.6.15
# google-api-core                          2.30.0
# google-api-python-client                 2.193.0
# google-auth                              2.49.1
# google-auth-httplib2                     0.3.0
# google-genai                             1.69.0
# google-generativeai                      0.8.6
# google-pasta                             0.2.0
# googleapis-common-protos                 1.72.0
# greenlet                                 3.3.2
# grpcio                                   1.76.0
# grpcio-status                            1.71.2
# h11                                      0.16.0
# h5py                                     3.15.1
# hf-xet                                   1.4.2
# httpcore                                 1.0.9
# httplib2                                 0.31.2
# httptools                                0.7.1
# httpx                                    0.28.1
# httpx-sse                                0.4.3
# huggingface_hub                          1.8.0
# idna                                     3.7
# immutabledict                            4.2.2
# importlib_metadata                       8.7.1
# importlib_resources                      6.5.2
# ipykernel                                6.30.1
# ipython                                  9.5.0
# ipython_pygments_lexers                  1.1.1
# ipywidgets                               8.1.7
# isoduration                              20.11.0
# jedi                                     0.19.2
# Jinja2                                   3.1.6
# jiter                                    0.13.0
# joblib                                   1.5.3
# json5                                    0.12.1
# jsonpatch                                1.33
# jsonpointer                              3.0.0
# jsonschema                               4.25.1
# jsonschema-specifications                2025.4.1
# jupyter                                  1.1.1
# jupyter_client                           8.6.3
# jupyter-console                          6.6.3
# jupyter_core                             5.8.1
# jupyter-events                           0.12.0
# jupyter-lsp                              2.3.0
# jupyter_server                           2.17.0
# jupyter_server_terminals                 0.5.3
# jupyterlab                               4.4.6
# jupyterlab_pygments                      0.3.0
# jupyterlab_server                        2.27.3
# jupyterlab_widgets                       3.0.15
# kaggle                                   2.0.1
# kagglehub                                0.3.13
# kagglesdk                                0.1.19
# keras                                    3.13.0
# keras-core                               0.1.7
# keras-cv                                 0.9.0
# kiwisolver                               1.4.9
# kubernetes                               35.0.0
# langchain                                1.2.13
# langchain-classic                        1.0.3
# langchain-community                      0.4.1
# langchain-core                           1.2.23
# langchain-openai                         1.1.12
# langchain-text-splitters                 1.1.1
# langgraph                                1.1.3
# langgraph-checkpoint                     4.0.1
# langgraph-prebuilt                       1.0.8
# langgraph-sdk                            0.3.12
# langsmith                                0.7.22
# lark                                     1.2.2
# libclang                                 18.1.1
# llvmlite                                 0.46.0
# lxml                                     6.1.0
# Markdown                                 3.10
# markdown-it-py                           4.0.0
# MarkupSafe                               3.0.2
# marshmallow                              3.26.2
# matplotlib                               3.10.8
# matplotlib-inline                        0.1.7
# mdurl                                    0.1.2
# mistune                                  3.1.4
# ml_dtypes                                0.5.4
# mmh3                                     5.2.1
# more-itertools                           10.8.0
# mpmath                                   1.3.0
# multidict                                6.7.1
# mypy_extensions                          1.1.0
# namex                                    0.1.0
# nbclient                                 0.10.2
# nbconvert                                7.16.6
# nbformat                                 5.10.4
# nest-asyncio                             1.6.0
# networkx                                 3.6.1
# notebook                                 7.4.5
# notebook_shim                            0.2.4
# numba                                    0.64.0
# numpy                                    2.2.6
# oauthlib                                 3.3.1
# onnxruntime                              1.24.4
# openai                                   2.30.0
# openai-whisper                           20250625
# opencv-python                            4.12.0.88
# opencv-python-headless                   4.10.0.84
# opentelemetry-api                        1.40.0
# opentelemetry-exporter-otlp-proto-common 1.40.0
# opentelemetry-exporter-otlp-proto-grpc   1.40.0
# opentelemetry-proto                      1.40.0
# opentelemetry-sdk                        1.40.0
# opentelemetry-semantic-conventions       0.61b0
# opt_einsum                               3.4.0
# optree                                   0.18.0
# orjson                                   3.11.7
# ormsgpack                                1.12.2
# overrides                                7.7.0
# packaging                                25.0
# pandas                                   2.3.3
# pandocfilters                            1.5.1
# parso                                    0.8.5
# pi_heif                                  1.1.1
# pillow                                   12.0.0
# pillow-avif-plugin                       1.5.2
# pip                                      25.3
# platformdirs                             4.4.0
# polars                                   1.36.1
# polars-runtime-32                        1.36.1
# prometheus_client                        0.22.1
# promise                                  2.3
# prompt_toolkit                           3.0.52
# propcache                                0.4.1
# proto-plus                               1.27.2
# protobuf                                 5.29.6
# psutil                                   7.0.0
# pure_eval                                0.2.3
# pyarrow                                  22.0.0
# pyasn1                                   0.6.3
# pyasn1_modules                           0.4.2
# pybase64                                 1.4.3
# pycparser                                2.22
# pydantic                                 2.12.5
# pydantic_core                            2.41.5
# pydantic-settings                        2.13.1
# pygbif                                   0.6.6
# Pygments                                 2.19.2
# PyMuPDF                                  1.27.2.2
# pyparsing                                3.3.1
# PyPika                                   0.51.1
# pyproject_hooks                          1.2.0
# python-dateutil                          2.9.0.post0
# python-dotenv                            1.2.1
# python-json-logger                       3.3.0
# python-slugify                           8.0.4
# pytz                                     2025.2
# pywin32                                  311
# pywinpty                                 3.0.0
# PyYAML                                   6.0.2
# pyzmq                                    27.0.2
# referencing                              0.36.2
# regex                                    2025.11.3
# requests                                 2.32.5
# requests-cache                           1.2.1
# requests-oauthlib                        2.0.0
# requests-toolbelt                        1.0.0
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rfc3987-syntax                           1.1.0
# rich                                     14.2.0
# roboflow                                 1.2.11
# rpds-py                                  0.27.1
# scikit-learn                             1.8.0
# scipy                                    1.16.3
# seaborn                                  0.13.2
# semantic-version                         2.10.0
# Send2Trash                               1.8.3
# setuptools                               80.9.0
# setuptools-rust                          1.12.0
# shellingham                              1.5.4
# simple-parsing                           0.1.7
# six                                      1.17.0
# sniffio                                  1.3.1
# soupsieve                                2.8
# SQLAlchemy                               2.0.48
# stack-data                               0.6.3
# sympy                                    1.14.0
# tenacity                                 9.1.4
# tensorboard                              2.20.0
# tensorboard-data-server                  0.7.2
# tensorflow                               2.20.0
# tensorflow-datasets                      4.9.9
# tensorflow-metadata                      1.17.2
# termcolor                                3.2.0
# terminado                                0.18.1
# text-unidecode                           1.3
# threadpoolctl                            3.6.0
# tiktoken                                 0.12.0
# tinycss2                                 1.4.0
# tokenizers                               0.22.2
# toml                                     0.10.2
# torch                                    2.9.1
# torchvision                              0.24.1
# tornado                                  6.5.2
# tqdm                                     4.67.1
# traitlets                                5.14.3
# typer                                    0.24.1
# types-python-dateutil                    2.9.0.20250822
# typing_extensions                        4.15.0
# typing-inspect                           0.9.0
# typing-inspection                        0.4.2
# tzdata                                   2025.2
# ultralytics                              8.3.241
# ultralytics-thop                         2.0.18
# uri-template                             1.3.0
# uritemplate                              4.2.0
# url-normalize                            2.2.1
# urllib3                                  2.5.0
# uuid_utils                               0.14.1
# uvicorn                                  0.42.0
# watchfiles                               1.1.1
# wcwidth                                  0.2.13
# webcolors                                24.11.1
# webencodings                             0.5.1
# websocket-client                         1.8.0
# websockets                               16.0
# Werkzeug                                 3.1.4
# wheel                                    0.45.1
# widgetsnbextension                       4.0.14
# wrapt                                    2.0.1
# xxhash                                   3.6.0
# yarl                                     1.23.0
# zipp                                     3.23.0
# zstandard                                0.25.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (c:\Users\VICTUS\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %% [markdown]
# # 2. Create and connect to a SQLite Database

# %%
# Step 1: Import the sqlite3 module 
import sqlite3 
# Step 2: Connect to (or create) a local database file named 'students.db' 
conn = sqlite3.connect("students.db") 
# Step 3: Create a cursor object to execute SQL commands 
cursor = conn.cursor() 
# Step 4: Display confirmation message 
print("Connected to students.db")
# Out:
# Connected to students.db

# %% [markdown]
# ## Try it pert for No. 2:

# %%
type(conn), type(cursor)
# Out:
# (sqlite3.Connection, sqlite3.Cursor)

# %% [markdown]
# # 3. Create a Table

# %%
# Step 1: Write the SQL command to create a table 
create_table_query = """ 
CREATE TABLE IF NOT EXISTS students ( 
    id INTEGER PRIMARY KEY AUTOINCREMENT, 
    full_name TEXT NOT NULL, 
    course TEXT NOT NULL, 
    year_level INTEGER NOT NULL 
) 
""" 
# Step 2: Execute the SQL command using the cursor 
cursor.execute(create_table_query) 
# Step 3: Commit the transaction to save changes 
conn.commit() 
# Step 4: Display success message 
print("Table 'students' created successfully.")
# Out:
# Table 'students' created successfully.

# %% [markdown]
# ## Try it part for No.3:

# %%
# Step 1: Query the database for existing tables 
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'") 
# Step 2: Fetch and display results 
print("Tables in database:", cursor.fetchall())
# Out:
# Tables in database: [('students',), ('sqlite_sequence',)]

# %% [markdown]
# # 4. Insert Sample Data into the Table

# %%
# Step 1: Define a list of sample student records (tuples) 
students = [ 
("Anna Reyes", "BS ECE", 3), 
("Carlos Dela Cruz", "BS EE", 2), 
("Mika Santos", "BS CE", 1) 
] 
# Step 2: Write a parameterized SQL INSERT query 
insert_query = """ 
INSERT INTO students (full_name, course, year_level) 
VALUES (?, ?, ?) 
""" 
# Step 3: Use executemany() to insert all records at once 
cursor.executemany(insert_query, students) 
# Step 4: Commit the transaction 
conn.commit() 
# Step 5: Display confirmation message 
print("Sample data inserted into 'students' table.")
# Out:
# Sample data inserted into 'students' table.

# %% [markdown]
# ## Try it part for No.4:

# %%
# Step 1: Query all records from the students table 
cursor.execute("SELECT * FROM students") 
# Step 2: Fetch and display the results 
rows = cursor.fetchall() 
for row in rows: 
    print(row)
# Out:
# (1, 'Anna Reyes', 'BS ECE', 4)
# (3, 'Mika Santos', 'BS CE', 2)
# (4, 'Anna Reyes', 'BS ECE', 4)
# (6, 'Mika Santos', 'BS CE', 2)
# (7, 'Anna Reyes', 'BS ECE', 3)
# (8, 'Carlos Dela Cruz', 'BS EE', 2)
# (9, 'Mika Santos', 'BS CE', 1)

# %% [markdown]
# # 5. Query the Data

# %%
# Step 1: Retrieve all records from the students table 
cursor.execute("SELECT * FROM students") 
print("All Students:") 
for row in cursor.fetchall(): 
    print(row) 
# Step 2: Filter results - show only BS ECE students 
cursor.execute("SELECT * FROM students WHERE course = 'BS ECE'") 
print("\nBS ECE Students:") 
print(cursor.fetchall()) 
# Step 3: Sort records by year_level in descending order 
cursor.execute("SELECT * FROM students ORDER BY year_level DESC") 
print("\nSorted by Year Level:") 
print(cursor.fetchall()) 
# Step 4: Limit the results to the top 2 records 
cursor.execute("SELECT * FROM students LIMIT 2") 
print("\nTop 2 Students:") 
print(cursor.fetchall())
# Out:
# All Students:
# (1, 'Anna Reyes', 'BS ECE', 4)
# (3, 'Mika Santos', 'BS CE', 2)
# (4, 'Anna Reyes', 'BS ECE', 4)
# (6, 'Mika Santos', 'BS CE', 2)
# (7, 'Anna Reyes', 'BS ECE', 3)
# (8, 'Carlos Dela Cruz', 'BS EE', 2)
# (9, 'Mika Santos', 'BS CE', 1)
#
# BS ECE Students:
# [(1, 'Anna Reyes', 'BS ECE', 4), (4, 'Anna Reyes', 'BS ECE', 4), (7, 'Anna Reyes', 'BS ECE', 3)]
#
# Sorted by Year Level:
# [(1, 'Anna Reyes', 'BS ECE', 4), (4, 'Anna Reyes', 'BS ECE', 4), (7, 'Anna Reyes', 'BS ECE', 3), (3, 'Mika Santos', 'BS CE', 2), (6, 'Mika Santos', 'BS CE', 2), (8, 'Carlos Dela Cruz', 'BS EE', 2), (9, 'Mika Santos', 'BS CE', 1)]
#
# Top 2 Students:
# [(1, 'Anna Reyes', 'BS ECE', 4), (3, 'Mika Santos', 'BS CE', 2)]

# %% [markdown]
# ## Try it part for No.5:

# %%
cursor.execute("SELECT * FROM students WHERE course = 'BS CE' AND year_level >= 1") 
print("Filtered list of BS COE students:") 
print(cursor.fetchall())
# Out:
# Filtered list of BS COE students:
# [(3, 'Mika Santos', 'BS CE', 2), (6, 'Mika Santos', 'BS CE', 2), (9, 'Mika Santos', 'BS CE', 1)]

# %% [markdown]
# # 6. Update and Delete Records

# %%
# Step 1: Update year level of a student 
cursor.execute(""" 
UPDATE students 
SET year_level = 4 
WHERE full_name = 'Anna Reyes' 
""") 
conn.commit() 
print("Updated Anna Reyes to 4th year.") 
# Step 2: Delete a student record 
cursor.execute(""" 
DELETE FROM students 
WHERE full_name = 'Carlos Dela Cruz' 
""") 
conn.commit() 
print("Deleted Carlos Dela Cruz from the database.")
# Out:
# Updated Anna Reyes to 4th year.
# Deleted Carlos Dela Cruz from the database.

# %% [markdown]
# ## Try it part for No.6:

# %%
cursor.execute(""" 
UPDATE students 
SET year_level = 2 
WHERE full_name = 'Mika Santos' 
""") 
conn.commit() 
print("Mika Santos has been updated to 2nd year.")
# Out:
# Mika Santos has been updated to 2nd year.

# %% [markdown]
# # 7. Use Aggregate Functions

# %%
# Step 1: Count total number of students 
cursor.execute("SELECT COUNT(*) FROM students") 
print("Total Students:", cursor.fetchone()[0]) 
# Step 2: Calculate the average year level 
cursor.execute("SELECT AVG(year_level) FROM students") 
print("Average Year Level:", cursor.fetchone()[0]) 
# Step 3: Group records by course 
cursor.execute("SELECT course, COUNT(*) FROM students GROUP BY course") 
print("Students per Course:", cursor.fetchall())
# Out:
# Total Students: 6
# Average Year Level: 3.0
# Students per Course: [('BS CE', 3), ('BS ECE', 3)]

# %% [markdown]
# ## Try it part for No.7:

# %%
cursor.execute("SELECT course, COUNT(*) FROM students GROUP BY course") 
print("Total number of students per course:") 
print(cursor.fetchall())
# Out:
# Total number of students per course:
# [('BS CE', 3), ('BS ECE', 3)]

# %% [markdown]
# # 8. Close the Database Connection

# %%
# Step 1: Close the cursor 
cursor.close() 
# Step 2: Close the connection 
conn.close() 
# Step 3: Display closing message 
print("Database connection closed.")
# Out:
# Database connection closed.

# %% [markdown]
# # 9. Insert Data via User Input

# %%
import sqlite3

conn = sqlite3.connect("students.db")

full_name = input("Enter full name: ")
course = input("Enter course (e.g., BS ECE): ")
year_level = int(input("Enter year level: "))

cursor = conn.cursor()

cursor.execute("""
INSERT INTO students (full_name, course, year_level)
VALUES (?, ?, ?)
""", (full_name, course, year_level))

conn.commit()
print("Student record successfully added.")

conn.close()
# Out:
# Student record successfully added.

# %% [markdown]
# # Try it part for No.9:

# %% [markdown]
# # 10. Reset Table Records for Testing

# %%
import sqlite3

# Re-establish the connection and cursor
conn = sqlite3.connect('students.db') 
cursor = conn.cursor()

# Now run your reset logic
cursor.execute("DELETE FROM students")
conn.commit()

# Reset the auto-increment counter
cursor.execute("DELETE FROM sqlite_sequence WHERE name='students'")
conn.commit()

print("All records deleted. ID counter reset.")
# Out:
# All records deleted. ID counter reset.

# %% [markdown]
# # 11. Export Query Results to CSV File

# %%
import csv 
# Step 1: Retrieve all records 
cursor.execute("SELECT * FROM students") 
rows = cursor.fetchall() 
# Step 2: Write to CSV 
with open("students_export.csv", "w", newline='') as file: 
    writer = csv.writer(file) 
    writer.writerow(["ID", "Full Name", "Course", "Year Level"]) 
    writer.writerows(rows) 
print("Data exported to 'students_export.csv'.")
# Out:
# Data exported to 'students_export.csv'.

# %% [markdown]
# # 12. Create and Join Tables

# %%
# Step 1: Create the courses table
cursor.execute("""
CREATE TABLE IF NOT EXISTS courses (
    course_code TEXT PRIMARY KEY,
    description TEXT NOT NULL
)
""")
conn.commit()

# Step 2: Insert data into the courses table
course_data = [
    ("BS ECE", "Electronics and Communications Engineering"),
    ("BS EE", "Electrical Engineering"),
    ("BS COE", "Computer Engineering"),
    ("BS CE", "Civil Engineering")
]

cursor.executemany("""
INSERT OR IGNORE INTO courses (course_code, description)
VALUES (?, ?)
""", course_data)
conn.commit()

# Step 3: Write a JOIN query to combine student names with their course descriptions
cursor.execute("""
SELECT s.full_name, s.course, c.description
FROM students s
JOIN courses c ON s.course = c.course_code
""")

# Step 4: Display results
for row in cursor.fetchall():
    print(row)

# %% [markdown]
# # 13. Create and Join Tables

# %%
# Step 1: Write a JOIN query with filtering and sorting 
cursor.execute(""" 
SELECT s.full_name, s.course, c.description 
FROM students s 
JOIN courses c ON s.course = c.course_code 
WHERE s.course = 'BS CE' 
ORDER BY s.full_name ASC 
""")
# Step 2: Display the filtered and sorted results 
for row in cursor.fetchall(): 
    print(row)

# %% [markdown]
# ## Try it part for No.13:

# %% [markdown]
# # 14. Search for Records Using Pattern Matching

# %%
# Part A – Static query (for demonstration only) 
cursor.execute(""" 
SELECT * FROM students 
WHERE full_name LIKE '%Reyes%' 
""") 
print("Static search result:") 
for row in cursor.fetchall(): 
    print(row) 

# Part B – Parameterized query with user input 
keyword = input("Enter a name keyword to search: ") 
cursor.execute(""" 
SELECT * FROM students 
WHERE full_name LIKE ? 
""", ('%' + keyword + '%',)) 
print("Search results:") 
for row in cursor.fetchall(): 
    print(row)
# Out:
# Static search result:
# Search results:

# %% [markdown]
# ## Try it part for No.14:
